# %%
import pandas as pd

# %%
data = pd.read_csv("REPORT.csv")
data
# Out:
#        ROWID Country  State lgd code  \
# 0          1   India               1
# 1          2   India               1
# 2          3   India               1
# 3          4   India               1
# 4          5   India               1
# ...      ...     ...             ...
# 20407  20408   India              38
# 20408  20409   India              38
# 20409  20410   India              38
# 20410  20411   India              38
# 20411  20412   India              38
#
#                                               State  YearCode  \
# 0                                 Jammu And Kashmir      2017
# 1                                 Jammu And Kashmir      2017
# 2                                 Jammu And Kashmir      2017
# 3                                 Jammu And Kashmir      2017
# 4                                 Jammu And Kashmir      2017
# ...                                             ...       ...
# 20407  The Dadra And Nagar Haveli And Daman And Diu      2023
# ...

# %%
data.isnull().sum()
# Out:
# ROWID                                        0
# Country                                      0
# State lgd code                               0
# State                                        0
# YearCode                                     0
# Year                                         0
# Type of area                                 0
# Gender                                       0
# Highest level of education completed         0
# Percentage distribution of persons          27
# Number of estimated persons              11664
# Number of sample persons                  5859
# Number of estimated persons excluding    14580
# Number of estimated persons including    14580
# Number of sample persons excluding       14580
# Number of sample persons including       14580
# dtype: int64
